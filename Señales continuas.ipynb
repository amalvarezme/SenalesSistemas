# %% [markdown]
# # Señales Continuas

# %% [markdown]
# ## Operaciones elementales
#
# Las operaciones como la superposición, el cambio temporal y el escalamiento, se utilizan para construir señales con una estructura más compleja [standard signals](standard_signals.ipynb). Se introduce un conjunto de operaciones elementales que se utilizan frecuentemente en el procesamiento de señales.

# %% [markdown]
# ### Superposición
#
# La superposición $x(t)$ de dos señales $x_1(t)$ and $x_2(t)$ está dada por:
#
# \begin{equation}
# x(t) = A \cdot x_1(t) + B \cdot x_2(t)
# \end{equation}
#
# con los pesos complejos $A, B \in \mathbb{C}$.

# %% [markdown]
# **Ejemplo**
#
# El siguiente ejemplo ilustra la superposición de dos señales armónicas $x(t) = A \cdot \cos(\omega_1 t) + B \cdot \cos(\omega_2 t)$ con pesos $A$, $B$ y frecuencia angular $\omega_1$ y $\omega_2$.

# %%
# %matplotlib inline
import sympy as sym

t = sym.symbols('t', real=True)

A = .3
om1 = 3
B = .5
om2 = 5

x = A*sym.cos(om1*t) + B*sym.cos(om2*t)


sym.plot(x, (t,-5,5), ylim=[-1.2, 1.2], ylabel=r'$x(t)$');

# %% [markdown]
# ### Desplazamiento temporal
#
# El desplazamiento temporal de una señal $s(t)$ en un instante de tiempo $\tau$ es una operación frecuentemente aplicada en el procesamiento de señales. Por ejemplo, para modelar la propagación de señales desde un actuador a un sensor. El desplazamiento de la señal $x(t)$ está definido como:
#
# \begin{equation}
# x(t) = s(t-\tau)
# \end{equation}
#
# con $\tau \in \mathbb{R}$. La señal $s(t)$ es:
#
# * desplazada hacia la derecha (*retrasada*) para $\tau > 0$
# * desplazada hacia la izquierda para $\tau < 0$

# %% [markdown]
# **Ejemplo**
#
# Para ilustrar el cambio temporal de señales, la contrucción de una señal escalera por una superposición de desplazamiento [rectangular signals](standard_signals.ipynb#Rectangular-Signal) es considerada:
#
# \begin{equation}
# x(t) = \text{rect}\left(t - \frac{1}{2} \right) + \frac{2}{3} \cdot \text{rect}\left(t-\frac{3}{2} \right) + \frac{1}{3} \cdot \text{rect} \left(t-\frac{5}{2} \right)
# \end{equation}

# %%
rect = sym.Heaviside(t + 0.5) - sym.Heaviside(t - 0.5)
sym.plot(rect, ylabel = 'rect')
x = rect.subs(t, t-1/2) + 2/3*rect.subs(t, t-3/2) + 1/3*rect.subs(t, t-5/2)

sym.plot(x, (t, -1, 5), ylim=[-0.2, 1.2], ylabel='$x(t)$');

# %% [markdown]
# **Ejercicio**
#
# * Agregar otro escalón al principio de la señal de escalera modificando el ejemplo anterior.

# %% [markdown]
# ### Escalamiento temporal
#
# El escalamiento temporal de una señal $s(t)$ está definido como:
#
# \begin{equation}
# x(t) = s(a \cdot t)
# \end{equation}
#
# con $a \in \mathbb{R}$. La señal $s(t)$ es
#
# * estirada para $0 < a < 1$
# * comprimida $a > 1$
# * invertida y escalada para $a < 0$
#
# Una aplicación de escalado temporal en el procesamiento de la señal es la escala de las señales estándar y el modelado del [Doppler effect](https://en.wikipedia.org/wiki/Doppler_effect).

# %% [markdown]
# **Ejemplo**
#
# El siguiente ejemplo ilustra el escalamiento de una señal escalera $y(t) = x(a \cdot t)$ introducida en el ejemplo anterior.

# %%
a = -1
y = x.subs(t, a*t)

px = sym.plot(x, (t, -3, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False, line_color='gray')
py = sym.plot(y.subs(a,1/2), (t, -3, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False)
px.extend(py)
px.show()

# %% [markdown]
# **Ejercicio**
#
# * Modifique el ejemplo anterior para que la señal se comprima.
# * Modifique el ejemplo anterior para que la señal se escale y se invierta. ¿Qué factor de escala `a`da como resultado un       estiramiento/compresión en este contexto?

# %% [markdown]
# ### Cambio temporal

# %% [markdown]
# El cambio temporal de una señal $s(t)$ está definido como
#
# \begin{equation}
# x(t) = s(\tau - t)
# \end{equation}
#
# para $\tau \in \mathbb{R}$. Como $s(\tau - t) = s(- (t - \tau))$ la operación de voltear también se puede representar como una inversión temporal de la señal $s(t)$ seguida por un desplazamiento de $\tau$ de la señal invertida. Para $\tau = 0$ este resultado es solo una inversión temporal de la señal
#
# La operación de cambio temporal puede interpretarse geométricamente como un reflejo de la señal $s(t)$ en el eje vertical $t=\frac{\tau}{2}$.

# %% [markdown]
# **Ejemplo**
#
# El siguiente ejemplo ilustra el cambio temporal $y(t) = x(\tau - t)$ de la señal escalera $x(t)$ anteriormente introducida.

# %%
tau =-1
y = x.subs(t, tau - t)

px=sym.plot(x, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', line_color='gray', show=False)
py=sym.plot(y, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False)
px.extend(py)
px.show()

# %% [markdown]
# **Ejercicio**
#
# * Para que valor de $\tau$, ¿la señal comienza en $t=0$?
# * Realice un cambio temporal dividiendo en dos operaciones consecutivas: (i) Inversión temporal and (ii) Desplazamiento temporal.

# %% [markdown]
# **Copyright**
#
# The notebook is provided as [Open Educational Resource](https://de.wikipedia.org/wiki/Open_Educational_Resources). Feel free to use the notebook for your own educational purposes. The text is licensed under [Creative Commons Attribution 4.0](https://creativecommons.org/licenses/by/4.0/), the code of the IPython examples under the [MIT license](https://opensource.org/licenses/MIT). Please attribute the work as follows: *Signals and Systems* by Sascha Spors.
