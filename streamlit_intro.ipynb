# %% [markdown]
# <a href="https://colab.research.google.com/github/amalvarezme/SenalesSistemas/blob/master/streamlit_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introducción a Streamlit**
#
# ![streamlit.png](data:image/png;base64,...)
#
# Streamlit es una herramienta de código abierto diseñada para ayudar a los desarrolladores a crear aplicaciones web interactivas y visuales de manera muy rápida y sencilla, usando el lenguaje de programación Python.
#
# En términos simples, imagina que tienes un análisis de datos, un modelo de machine learning, o cualquier script en Python y quieres compartirlo con otros de manera visual e interactiva (sin necesidad de que ellos instalen Python o ejecuten el código). Streamlit te permite tomar ese código y transformarlo en una aplicación web funcional con solo unas pocas líneas.
#
# **¿Para qué sirve Streamlit?**
#
# - Crear interfaces visuales para proyectos en Python: Puedes mostrar gráficos, botones, formularios, tablas, etc.
# - Compartir proyectos interactivos: Los usuarios pueden interactuar con tus datos o modelos a través de la web sin saber programar.
# - Prototipar rápido: En lugar de construir toda una página web desde cero, Streamlit facilita la creación de prototipos de manera rápida.

# %% [markdown]
# ## Instalación de Streamlit

# %%
# !pip install streamlit -q # El comando pip install streamlit -q se utiliza para instalar el paquete Streamlit ya que no viene por defecto en python
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 30.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 34.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 2.8 MB/s eta 0:00:00

# %% [markdown]
# ## Creación de un archivo `.py`
#
# El archivo `.py` contendrá todo el código necesario para construir y ejecutar la aplicación con **Streamlit**. En él, podrás incluir elementos como:
#
# - Texto que deseas mostrar en la aplicación.
# - Comandos y lógica para controlar el flujo de la app.
# - Widgets interactivos (botones, sliders, etc.).
# - Gráficas, tablas y otras visualizaciones de datos.
#
# Este archivo será el corazón de la aplicación, ya que define su estructura, contenido y comportamiento.

# %%
# %%writefile primer_streamlit.py
import streamlit as st

# Título de la app
st.title("Mi primera aplicación con Streamlit")

# Texto introductorio
st.write("¡Bienvenidos a mi aplicación interactiva!")

# Agregar un botón
if st.button("Presiona aquí"):
    st.write("¡El botón ha sido presionado!")

# Agregar un área de entrada de texto
user_input = st.text_input("Ingresa tu nombre y presiona enter:", "")
if user_input:
    st.write(f"¡Hola, {user_input}!")

# Agregar una sección para una calculadora simple
st.write("### Calculadora simple")

# Entradas para los números
num1 = st.number_input("Ingresa el primer número", value=0)
num2 = st.number_input("Ingresa el segundo número", value=0)

# Botón para sumar los números
if st.button("Sumar"):
    resultado = num1 + num2
    st.write(f"El resultado de la suma es: {resultado}")

# Texto final
st.write("Puedes incluir cualquier contenido en esta aplicación, incluyendo cálculos, visualizaciones, e interacción con el usuario.")
# Out:
# Writing primer_streamlit.py

# %% [markdown]
# ## Ejecución de una aplicación provisional en Streamlit
#
# Sigue estos pasos para ejecutar tu aplicación de **Streamlit** y acceder a ella a través de un túnel local:
#
# 1. **Ejecuta el siguiente comando en la terminal**:
#    ```bash
#    !streamlit run primer_streamlit.py & npx localtunnel --port 8501
#
# Asegúrate de reemplazar primer_streamlit.py por el nombre del archivo .py que hayas creado.
#
# 2. **Instalación de paquetes adicionales**: La primera vez que ejecutes este comando, se te pedirá que instales un paquete adicional. Escribe "y" y presiona "Enter" para proceder con la instalación.
#
# ![2..png](data:image/png;base64,...)
#
# 3. **Accede al enlace provisional**: Una vez que la aplicación esté corriendo, LocalTunnel generará un enlace temporal. Haz clic o copia ese enlace para acceder a tu aplicación en el navegador (cada vez que corras la celda, el link podrá ser diferente).
#
# ![3..png](data:image/png;base64,...)
#
# 4. **Ingresa la contraseña**: El navegador te pedirá una contraseña. Usa los números y puntos que aparecieron en la consola de tu terminal al ejecutar el comando.
#
# ![4..png](data:image/png;base64,...)
#
# 5. Finalmente, ya tienes tu primera aplicación en Streamlit.
#
# ![image.png](data:image/png;base64,...)
#
# **Nota:**
# Ten en cuenta que para poder entrar a tu página, debe estar ejecutándose la celda, por ello no queda un enlace permanenete y la llamamos "provisional".

# %%
# !streamlit run primer_streamlit.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.138.62.90:8501
#
# Need to install the following packages:
#   localtunnel@2.0.2
# Ok to proceed? (y) y
# your url is: https://wise-ties-relax.loca.lt
#   Stopping...
# ^C
